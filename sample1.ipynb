# %%
from google.colab import drive
drive.mount('/content/gdrive')
! pip install spacy
import pandas as pd

dft=pd.read_csv("/content/gdrive/MyDrive/data_by_artist.csv (1).zip")
dft
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#        mode  count  acousticness  \
# 0         1      9      0.590111
# 1         1     26      0.862538
# 2         1      7      0.856571
# 3         1     27      0.884926
# 4         1      7      0.510714
# ...     ...    ...           ...
# 28675     1      2      0.512000
# 28676     0      2      0.541000
# 28677     1     11      0.785455
# 28678     1      2      0.381000
# 28679     1      2      0.568000
#
#                                                  artists  danceability  \
# 0                       "Cats" 1981 Original London Cast      0.467222
# 1                              "Cats" 1983 Broadway Cast      0.441731
# 2            "Fiddler On The Roof” Motion Picture Chorus      0.348286
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dft.head(10)
# Out:
#    mode  count  acousticness  \
# 0     1      9      0.590111
# 1     1     26      0.862538
# 2     1      7      0.856571
# 3     1     27      0.884926
# 4     1      7      0.510714
# 5     1     36      0.609556
# 6     1      2      0.725000
# 7     1      2      0.927000
# 8     1    122      0.173145
# 9     1     15      0.544467
#
#                                              artists  danceability  \
# 0                   "Cats" 1981 Original London Cast      0.467222
# 1                          "Cats" 1983 Broadway Cast      0.441731
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.348286
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.425074
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.467143
# 5  "Joseph And The Amazing Technicolor Dreamcoat"...      0.487278
# 6                             "Mama" Helen Teagarden      0.637000
# 7                            "Test for Victor Young"      0.734000
# ...

# %%
dft.tail(10)
# Out:
#        mode  count  acousticness artists  danceability    duration_ms  energy  \
# 28670     0      2      0.911000   須永ひろし      0.673000  413800.000000  0.1350
# 28671     0      2      0.028100    須田景凪      0.559000  209636.000000  0.8730
# 28672     1      2      0.686000     高慧君      0.520000  286840.000000  0.2850
# 28673     1      2      0.884000     鳳飛飛      0.358000  259387.000000  0.2080
# 28674     0      2      0.006550     鹿谷樹      0.603000  206180.000000  0.9640
# 28675     1      2      0.512000     麥志誠      0.356000  198773.000000  0.3060
# 28676     0      2      0.541000     黃品源      0.578000  293840.000000  0.3340
# 28677     1     11      0.785455     黃國隆      0.570818  174582.727273  0.1484
# 28678     1      2      0.381000      黑豹      0.353000  316160.000000  0.6860
# 28679     1      2      0.568000     조정현      0.447000  237688.000000  0.2150
#
#        instrumentalness  liveness   loudness  speechiness       tempo  \
# ...

# %%
dft["artists"]
# Out:
# 0                         "Cats" 1981 Original London Cast
# 1                                "Cats" 1983 Broadway Cast
# 2              "Fiddler On The Roof” Motion Picture Chorus
# 3           "Fiddler On The Roof” Motion Picture Orchestra
# 4        "Joseph And The Amazing Technicolor Dreamcoat"...
#                                ...
# 28675                                                  麥志誠
# 28676                                                  黃品源
# 28677                                                  黃國隆
# 28678                                                   黑豹
# 28679                                                  조정현
# Name: artists, Length: 28680, dtype: object

# %%
dft["artists"].head(10)
# Out:
# 0                     "Cats" 1981 Original London Cast
# 1                            "Cats" 1983 Broadway Cast
# 2          "Fiddler On The Roof” Motion Picture Chorus
# 3       "Fiddler On The Roof” Motion Picture Orchestra
# 4    "Joseph And The Amazing Technicolor Dreamcoat"...
# 5    "Joseph And The Amazing Technicolor Dreamcoat"...
# 6                               "Mama" Helen Teagarden
# 7                              "Test for Victor Young"
# 8                                  "Weird Al" Yankovic
# 9                                                 $NOT
# Name: artists, dtype: object

# %%
dft[['artists','energy']]
# Out:
#                                                  artists    energy
# 0                       "Cats" 1981 Original London Cast  0.394003
# 1                              "Cats" 1983 Broadway Cast  0.406808
# 2            "Fiddler On The Roof” Motion Picture Chorus  0.286571
# 3         "Fiddler On The Roof” Motion Picture Orchestra  0.245770
# 4      "Joseph And The Amazing Technicolor Dreamcoat"...  0.488286
# ...                                                  ...       ...
# 28675                                                麥志誠  0.306000
# 28676                                                黃品源  0.334000
# 28677                                                黃國隆  0.148400
# 28678                                                 黑豹  0.686000
# 28679                                                조정현  0.215000
#
# [28680 rows x 2 columns]
